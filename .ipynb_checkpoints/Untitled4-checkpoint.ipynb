# %%
import gempy as gp
import numpy as np
import matplotlib.pyplot as plt

# %%
geomodel = gp.create_model("X-field")

# %%
basedir = 'model_input/'

# %%
gp.init_data(geomodel, [5000., 20000.,2500.,12500.,9000.,12000.], [100,100,100],
            path_i = basedir + 'welloc.csv',
            path_o = basedir + 'orientations.csv',
            default_values=True)
# Out:
# Active grids: ['regular']
# X-field  2019-10-26 12:31

# %%
gp.get_data(geomodel, 'surface_points')
# Out:
#                 X            Y        Z       X_r       Y_r       Z_r  \
# 0    10532.520904  7213.263430   9896.0  0.492138  0.353714  0.452176
# 1    10532.520904  7213.263430   9996.0  0.492138  0.353714  0.459856
# 2    10532.520904  7213.263430  10000.0  0.492138  0.353714  0.460163
# 3    10532.520904  7213.263430  10050.0  0.492138  0.353714  0.464003
# 4    10532.520904  7213.263430  10087.0  0.492138  0.353714  0.466845
# ..            ...          ...      ...       ...       ...       ...
# 126  10532.520904  7213.263430  10567.0  0.492138  0.353714  0.503710
# 127  10532.520904  7213.263430  10567.5  0.492138  0.353714  0.503748
# 128  11584.500000  8892.310000   9810.0  0.572932  0.482668  0.445571
# 129  11663.572861  8750.193989  10300.0  0.579005  0.471753  0.483204
# 130  11668.349359  8741.612575  11500.0  0.579372  0.471094  0.575366
#
#        surface          series  id  order_series        smooth
# 0        chalk  Default series   1             1  1.000000e-08
# 1        chalk  Default series   1             1  1.000000e-08
# 2        chalk  Default series   1             1  1.000000e-08
# 3        chalk  Default series   1             1  1.000000e-08
# 4        chalk  Default series   1             1  1.000000e-08
# ..         ...             ...  ..           ...           ...
# 126  main_sand  Default series   4             1  1.000000e-08
# 127  main_sand  Default series   4             1  1.000000e-08
# 128     fault1  Default series   5             1  1.000000e-08
# 129     fault1  Default series   5             1  1.000000e-08
# 130     fault1  Default series   5             1  1.000000e-08
#
# [131 rows x 11 columns]

# %%
geomodel.surfaces
# Out:
#            surface          series  order_surfaces  isBasement    color vertices edges  id
# 0            chalk  Default series               1       False  #015482      NaN   NaN   1
# 1  kimmeredge_clay  Default series               2       False  #9f0052      NaN   NaN   2
# 2      ribble_sand  Default series               3       False  #ffbe00      NaN   NaN   3
# 3        main_sand  Default series               4       False  #728f02      NaN   NaN   4
# 4           fault1  Default series               5       False  #443988      NaN   NaN   5
# 5         basement        Basement               1        True  #ff3f20      NaN   NaN   6

# %%
gp.map_series_to_surfaces(geomodel,{"Fault_Series":'fault1', 
                             "Strat_Series": ('chalk','kimmeredge_clay',
                                              'ribble_sand', 'main_sand', 'basement')}, remove_unused_series=True)
# Out:
#            surface        series  order_surfaces  isBasement    color vertices edges  id
# 4           fault1  Fault_Series               1       False  #443988      NaN   NaN   1
# 0            chalk  Strat_Series               1       False  #015482      NaN   NaN   2
# 1  kimmeredge_clay  Strat_Series               2       False  #9f0052      NaN   NaN   3
# 2      ribble_sand  Strat_Series               3       False  #ffbe00      NaN   NaN   4
# 3        main_sand  Strat_Series               4       False  #728f02      NaN   NaN   5
# 5         basement  Strat_Series               5        True  #ff3f20      NaN   NaN   6

# %%
geomodel.grid
# Out:
# Grid Object. Values:
# array([[ 5075.,  2550.,  9015.],
#        [ 5075.,  2550.,  9045.],
#        [ 5075.,  2550.,  9075.],
#        ...,
#        [19925., 12450., 11925.],
#        [19925., 12450., 11955.],
#        [19925., 12450., 11985.]])

# %%
gp.plot.plot_data(geomodel, direction='y')

# %%
gp.set_interpolation_data(geomodel,
                          compile_theano=True,
                          theano_optimizer='fast_compile',
                          verbose=[])
# Out:
# Compiling theano function...
# Compilation Done!

# %%
gp.get_data(geomodel, 'kriging')
# Out:
#                       values
# range                18275.7
# $C_o$            7.95238e+06
# drift equations       [3, 3]
# nugget grad             0.01
# nugget scalar          1e-06

# %%
sol = gp.compute_model(geomodel, compute_mesh=True)
# Out:
# /home/mirzakhan/.local/share/virtualenvs/Stdlog-xUKvEn9n/lib/python3.6/site-packages/gempy/core/solution.py:253: UserWarning: Attribute error. Using non masked marching cubesmarching_cubes_lewiner() got an unexpected keyword argument 'mask'
#   warnings.warn('Attribute error. Using non masked marching cubes' + str(e))

# %%
# Out:
# Lithology ids
#   [2. 2. 2. ... 1. 1. 1.]

# %%
# %matplotlib inline
gp.plot.plot_section(geomodel, cell_number=25,
                     direction='y', show_data=True)

# %%
gp.plot.plot_map(geomodel)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-3eddee2b24c9> in <module>
# ----> 1 gp.plot.plot_map(geomodel)
#
# ~/.local/share/virtualenvs/Stdlog-xUKvEn9n/lib/python3.6/site-packages/gempy/plot/plot.py in plot_map(model, contour_lines, show_faults, show_data)
#     202 def plot_map(model, contour_lines=True, show_faults = True, show_data=True):
#     203     plot = PlotSolution(model)
# --> 204     plot.plot_map(contour_lines=contour_lines, show_faults=show_faults, show_data=show_data)
#     205
#     206
#
# ~/.local/share/virtualenvs/Stdlog-xUKvEn9n/lib/python3.6/site-packages/gempy/plot/visualization_2d.py in plot_map(self, solution, contour_lines, show_faults, show_data)
#     609         else:
#     610             solution = self.model.solutions
# --> 611         geomap = solution.geological_map.reshape(self.model.grid.topography.values_3D[:, :, 2].shape)
#     612         if show_data:
#     613             self.plot_data(direction='z')
#
# AttributeError: 'NoneType' object has no attribute 'reshape'
